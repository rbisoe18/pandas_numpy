# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
ls
# Out:
# sample_data/

# %%
df1.to_csv('NBA.csv',index = False)

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
l
# Out:
# [               Player       Span  Mat Inns  NO  Runs   HS    Ave   BF      SR  \
#  0          AB Agarkar  2006-2007    4    2   0    15   14   7.50   11  136.36
#  1            KK Ahmed  2018-2019   14    1   1     1   1*      -    1  100.00
#  2           S Aravind  2015-2015    1    -   -     -    -      -    -       -
#  3      Arshdeep Singh  2022-2022   21    4   4     6   2*      -    4  150.00
#  4            R Ashwin  2010-2022   65   19  12   184  31*  26.28  160  115.00
#  ..                ...        ...  ...  ...  ..   ...  ...    ...  ...     ...
#  94      R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4   50.00
#  95  Washington Sundar  2017-2022   32   12   4    47  14*   5.87   33  142.42
#  96           SA Yadav  2021-2022   42   40   8  1408  117  44.00  778  180.97
#  97           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21  104.76
#  98       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863  136.38
#
#     100  50  0   4s  6s
#  0    0   0  0    2   0
#  1    0   0  0    0   0
#  2    -   -  -    -   -
#  3    0   0  0    0   0
#  4    0   0  0   17   4
#  ..  ..  .. ..  ...  ..
#  94   0   0  0    0   0
#  95   0   0  4    4   3
#  96   2  12  3  131  80
#  97   0   0  0    2   0
#  98   0   8  1   77  74
#
#  [99 rows x 15 columns],                                                    0
#  0  By default, the shading indicates records from...
#  1  Adjust:  most recent  | past week  | past mont...,                                                    0
#  0  Records includes the following current or rece...
#  1  New Zealand v India at Napier, 3rd T20I, Nov 2...
#  2  New Zealand v India at Mount Maunganui, 2nd T2...
#  3  England v India at Adelaide, ICC Men's T20 Wor...]

# %%
len(l)
# Out:
# 3

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  New Zealand v India at Napier, 3rd T20I, Nov 2...
# 2  New Zealand v India at Mount Maunganui, 2nd T2...
# 3  England v India at Adelaide, ICC Men's T20 Wor...

# %%
l[0]
# Out:
#                Player       Span  Mat Inns  NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2   0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1   1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -   -     -    -      -    -       -
# 3      Arshdeep Singh  2022-2022   21    4   4     6   2*      -    4  150.00
# 4            R Ashwin  2010-2022   65   19  12   184  31*  26.28  160  115.00
# ..                ...        ...  ...  ...  ..   ...  ...    ...  ...     ...
# 94      R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4   50.00
# 95  Washington Sundar  2017-2022   32   12   4    47  14*   5.87   33  142.42
# 96           SA Yadav  2021-2022   42   40   8  1408  117  44.00  778  180.97
# 97           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21  104.76
# 98       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863  136.38
#
#    100  50  0   4s  6s
# 0    0   0  0    2   0
# 1    0   0  0    0   0
# 2    -   -  -    -   -
# 3    0   0  0    0   0
# 4    0   0  0   17   4
# ..  ..  .. ..  ...  ..
# 94   0   0  0    0   0
# 95   0   0  4    4   3
# 96   2  12  3  131  80
# 97   0   0  0    2   0
# 98   0   8  1   77  74
#
# [99 rows x 15 columns]

# %%
l[0].to_csv('cricket.csv' , index = False)

# %%
d ="""{"name" : "Rajat Bisoe" , 
"email id " : "rbisoer@gmail.com",
"tech" : ["ML" , "DL" , "CV" , "NLP", "RL", "BD", "DA" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
d
# Out:
# '{"name" : "Rajat Bisoe" , \n"email id " : "rbisoer@gmail.com",\n"tech" : ["ML" , "DL" , "CV" , "NLP", "RL", "BD", "DA" ],\n"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]\n}'

# %%
type(d)
# Out:
# str

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-3449b472dc69> in <module>
# ----> 1 pd.DataFrame(d)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %% [markdown]
# ---

# %%
import json

# %%
d ="""{"name" : "Rajat Bisoe" , 
"email id " : "rbisoer@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'Rajat Bisoe',
#  'email id ': 'rbisoer@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
type(d)
# Out:
# str

# %%
pd.DataFrame(result)
# Out:
#           name          email id  tech   plateform
# 0  Rajat Bisoe  rbisoer@gmail.com   ML  techneuron
# 1  Rajat Bisoe  rbisoer@gmail.com   DL  kidsneuron
# 2  Rajat Bisoe  rbisoer@gmail.com   CV     ineuron

# %%
result["name"]
# Out:
# 'Rajat Bisoe'

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d1 = d["data"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d['data']])
# Out:
#   File "<ipython-input-4-c79b3c01ceb6>", line 1
#     pd.DataFrame(d['data']])
#                           ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-17ddab1ee376> in <module>
# ----> 1 pd.DataFrame(d1)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ---

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-442de89f72d9> in <module>
# ----> 1 pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ---

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50445',
#   'id': 1511387003,
#   'node_id': 'PR_kwDOAA0YD85GOaOX',
#   'number': 50445,
#   'title': 'TST: Add test_ to four tests in test_readlines.py and fix two of them',
#   'user': {'login': 'phershbe',
#    'id': 25594870,
#    'node_id': 'MDQ6VXNlcjI1NTk0ODcw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25594870?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phershbe',
#    'html_url': 'https://github.com/phershbe',
#    'followers_url': 'https://api.github.com/users/phershbe/followers',
#    'following_url': 'https://api.github.com/users/phershbe/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phershbe/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phershbe/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phershbe/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phershbe/orgs',
#    'repos_url': 'https://api.github.com/users/phershbe/repos',
#    'events_url': 'https://api.github.com/users/phershbe/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phershbe/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 53,
#    'closed_issues': 855,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2022-12-27T08:16:07Z',
#    'due_on': '2023-01-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-12-27T03:03:14Z',
#   'updated_at': '2022-12-27T07:51:45Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50445',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50445',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50445.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50445.patch',
#    'merged_at': None},
#   'body': "Four tests in https://github.com/pandas-dev/pandas/blob/main/pandas/tests/io/json/test_readlines.py weren't running because they didn't have `test_` in front of their names, fixed those.\r\n\r\nTwo of those tests were not passing because the JSON data was turning booleans into 1s and 0s which was conflicting with the booleans in the compared data, so added `int` before all of the booleans in the compared data. Had detailed comments explaining this but shortened them in order to pass Flake8.\r\n\r\n- [x] closes #50378\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50444',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50444/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50444/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50444/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50444',
#   'id': 1511382949,
#   'node_id': 'PR_kwDOAA0YD85GOZZ0',
#   'number': 50444,
#   'title': 'BUG: groupby.nth with NA values in groupings after subsetting to SeriesGroupBy',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 53,
#    'closed_issues': 855,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2022-12-27T08:16:07Z',
#    'due_on': '2023-01-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-12-27T02:53:32Z',
#   'updated_at': '2022-12-27T02:53:32Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50444',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50444',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50444.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50444.patch',
#    'merged_at': None},
#   'body': '- [x] closes #26454 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50444/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50444/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50443',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50443/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50443/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50443/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50443',
#   'id': 1511235443,
#   'node_id': 'PR_kwDOAA0YD85GN6Kf',
#   'number': 50443,
#   'title': 'TST: Verify isin returns consistent results for passed iterables',
#   'user': {'login': 'jessica-writes-code',
#    'id': 10662138,
#    'node_id': 'MDQ6VXNlcjEwNjYyMTM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10662138?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jessica-writes-code',
#    'html_url': 'https://github.com/jessica-writes-code',
#    'followers_url': 'https://api.github.com/users/jessica-writes-code/followers',
#    'following_url': 'https://api.github.com/users/jessica-writes-code/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jessica-writes-code/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jessica-writes-code/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jessica-writes-code/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jessica-writes-code/orgs',
#    'repos_url': 'https://api.github.com/users/jessica-writes-code/repos',
#    'events_url': 'https://api.github.com/users/jessica-writes-code/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jessica-writes-code/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 986278782,
#     'node_id': 'MDU6TGFiZWw5ODYyNzg3ODI=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Tests',
#     'name': 'Needs Tests',
#     'color': 'cdea3c',
#     'default': False,
#     'description': 'Unit test(s) needed to prevent regressions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-26T20:54:01Z',
#   'updated_at': '2022-12-27T08:22:25Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50443',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50443',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50443.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50443.patch',
#    'merged_at': None},
#   'body': 'Add tests to verify that the `Series` method `isin` returns consistent results when passed iterables with different dtypes. (See #50234.)\r\n\r\n- [ ] closes #50234\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] ~Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.~ (Not applicable.)\r\n- [x] ~Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.~ (Not applicable.)\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50443/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50443/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50442',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50442/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50442/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50442/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50442',
#   'id': 1511176496,
#   'node_id': 'I_kwDOAA0YD85aErkw',
#   'number': 50442,
#   'title': 'BUG: Using datetime global in query expression raises UndefinedVariableError',
#   'user': {'login': 'phillipuniverse',
#    'id': 684275,
#    'node_id': 'MDQ6VXNlcjY4NDI3NQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/684275?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phillipuniverse',
#    'html_url': 'https://github.com/phillipuniverse',
#    'followers_url': 'https://api.github.com/users/phillipuniverse/followers',
#    'following_url': 'https://api.github.com/users/phillipuniverse/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phillipuniverse/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phillipuniverse/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phillipuniverse/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phillipuniverse/orgs',
#    'repos_url': 'https://api.github.com/users/phillipuniverse/repos',
#    'events_url': 'https://api.github.com/users/phillipuniverse/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phillipuniverse/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-12-26T19:18:47Z',
#   'updated_at': '2022-12-26T20:38:23Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\ndef test_reproduction():\r\n    unfiltered = DataFrame(\r\n        {\r\n            "planned_date": {\r\n                "0": date.fromisoformat("2020-10-01"),\r\n                "1": date.fromisoformat("2020-08-01"),\r\n            },\r\n        }\r\n    )\r\n    filtered = unfiltered.query(f\'planned_date >= datetime.strptime("2020-09-01", "%Y-%m-%d").date()\')\\\r\n        .copy().reset_index(drop=True)\r\n    assert (\r\n        filtered.to_json()\r\n        == unfiltered.iloc[[0]].reset_index(drop=True).to_json()\r\n    )\r\n```\r\n\r\nThis results in the following exception, whereas on versions before 1.5.0 it works\r\n```\r\n            except KeyError as err:\r\n>               raise UndefinedVariableError(key, is_local) from err\r\nE               pandas.errors.UndefinedVariableError: name \'datetime\' is not defined\r\n```\r\n\r\n### Issue Description\r\n\r\nThe behavior change in #47273 appears to make it to where I cannot use the `datetime` global in a query string being passed to eval. I\'m also just not sure what the right way is to now access globals within an eval, is there a better way to write this query?\r\n\r\n### Expected Behavior\r\n\r\nTest passes\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 91111fd99898d9dcaa6bf6bedb662db4108da6e6\r\npython           : 3.9.16.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.1.0\r\nVersion          : Darwin Kernel Version 22.1.0: Sun Oct  9 20:14:54 PDT 2022; root:xnu-8792.41.9~2/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.1\r\nnumpy            : 1.23.0\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.6.3\r\npip              : 22.1.2\r\nCython           : None\r\npytest           : 6.2.5\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.0\r\nhtml5lib         : None\r\npymysql          : 1.0.2\r\npsycopg2         : 2.9.3\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.5.2\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 10.0.1\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.5.4\r\nsnappy           : None\r\nsqlalchemy       : 1.4.39\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50442/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50442/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50441',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50441/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50441/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50441/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50441',
#   'id': 1511148698,
#   'node_id': 'PR_kwDOAA0YD85GNmw5',
#   'number': 50441,
#   'title': 'REF: share TimedeltaArray division code',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-26T18:45:00Z',
#   'updated_at': '2022-12-27T01:17:37Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50441',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50441',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50441.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50441.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50441/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50441/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50440',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50440/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50440/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50440/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50440',
#   'id': 1511090425,
#   'node_id': 'PR_kwDOAA0YD85GNaBH',
#   'number': 50440,
#   'title': 'BUG: Fix issue where df.groupby.resample.size returns wide DF instead of MultiIndex Series.',
#   'user': {'login': 'dicristina',
#    'id': 74217512,
#    'node_id': 'MDQ6VXNlcjc0MjE3NTEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74217512?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dicristina',
#    'html_url': 'https://github.com/dicristina',
#    'followers_url': 'https://api.github.com/users/dicristina/followers',
#    'following_url': 'https://api.github.com/users/dicristina/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dicristina/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dicristina/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dicristina/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dicristina/orgs',
#    'repos_url': 'https://api.github.com/users/dicristina/repos',
#    'events_url': 'https://api.github.com/users/dicristina/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dicristina/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-26T17:07:53Z',
#   'updated_at': '2022-12-26T19:41:53Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50440',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50440',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50440.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50440.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46826  (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50440/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50440/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50439',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50439/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50439/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50439/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50439',
#   'id': 1511026179,
#   'node_id': 'PR_kwDOAA0YD85GNMQe',
#   'number': 50439,
#   'title': 'CLN, TST: clean up and increase coverage in tslib.pyx',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-26T15:08:32Z',
#   'updated_at': '2022-12-26T18:49:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50439',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50439',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50439.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50439.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50439/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50439/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50437',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50437/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50437/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50437/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50437',
#   'id': 1510379713,
#   'node_id': 'PR_kwDOAA0YD85GLB9K',
#   'number': 50437,
#   'title': 'BUG: Series(pyarrow-backed).round raising AttributeError',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-25T17:44:10Z',
#   'updated_at': '2022-12-25T17:44:45Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50437',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50437',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50437.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50437.patch',
#    'merged_at': None},
#   'body': '- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nAdding `ArrowExtensionArray.round` to fix the following:\r\n\r\n```\r\nimport pandas as pd\r\n\r\npd.Series([1.23], dtype="float64[pyarrow]").round(1)\r\n\r\n# AttributeError: \'ArrowExtensionArray\' object has no attribute \'round\'\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50437/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50437/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50436',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50436/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50436/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50436/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50436',
#   'id': 1510306930,
#   'node_id': 'PR_kwDOAA0YD85GKzuQ',
#   'number': 50436,
#   'title': 'TST: Make get_array smarter to work for masked arrays',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-25T11:29:03Z',
#   'updated_at': '2022-12-25T11:29:03Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50436',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50436',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50436.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50436.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis should work ootb when testing with masked arrays',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50436/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50436/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50435',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50435/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50435/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50435/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50435',
#   'id': 1510302903,
#   'node_id': 'PR_kwDOAA0YD85GKy8j',
#   'number': 50435,
#   'title': ' BUG: inconsistent handling of exact=False case in to_datetime parsing',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-25T11:06:42Z',
#   'updated_at': '2022-12-26T15:15:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50435',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50435',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50435.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50435.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #50412 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nHaven't added a whatsnew note, as `exact` never worked to begin with for ISO8601 formats, and this just corrects #49333",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50435/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50435/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50433',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50433/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50433/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50433/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50433',
#   'id': 1510215965,
#   'node_id': 'PR_kwDOAA0YD85GKiqp',
#   'number': 50433,
#   'title': 'CLN: Assorted',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-25T00:31:44Z',
#   'updated_at': '2022-12-27T01:25:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50433',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50433',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50433.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50433.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50433/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50433/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50432',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50432/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50432/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50432/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50432',
#   'id': 1510180067,
#   'node_id': 'PR_kwDOAA0YD85GKcDV',
#   'number': 50432,
#   'title': 'ENH: Add lazy copy to align',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-24T19:42:48Z',
#   'updated_at': '2022-12-24T19:42:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50432',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50432',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50432.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50432.patch',
#    'merged_at': None},
# ...
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50410/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50410/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50410',
#   'id': 1509310192,
#   'node_id': 'I_kwDOAA0YD85Z9j7w',
#   'number': 50410,
#   'title': 'Datetime parsing (PDEP-4): should time strings be inferred?',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 53,
#    'closed_issues': 855,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2022-12-27T08:16:07Z',
#    'due_on': '2023-01-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2022-12-23T12:43:42Z',
#   'updated_at': '2022-12-23T15:01:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "Example with latest main (this now raises a warning, the actual result is the same as on released pandas):\r\n\r\n```\r\n>>> pd.to_datetime(['09:00', '09:30', '10:00'])\r\n<stdin>:1: UserWarning: Could not infer format, so each element will be parsed individually by `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.\r\nDatetimeIndex(['2022-12-23 09:00:00', '2022-12-23 09:30:00',\r\n               '2022-12-23 10:00:00'],\r\n              dtype='datetime64[ns]', freq=None)\r\n```\r\n\r\nThe above actually has a consistent format, but not one we can infer at the moment. Should we? \r\n\r\n(saw this warning in pyarrow's CI, we were using `to_datetime` to parse time strings into datetime.time objects, by directly accessing `.time()`, so the actual date didn't matter in that use case)\r\n\r\ncc @MarcoGorelli \r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50410/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50410/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50409',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50409/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50409/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50409/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50409',
#   'id': 1509146751,
#   'node_id': 'I_kwDOAA0YD85Z88B_',
#   'number': 50409,
#   'title': "BUG: Read_csv won't warn/skip bad lines when nrows is being used",
#   'user': {'login': 'd2thebee',
#    'id': 79337886,
#    'node_id': 'MDQ6VXNlcjc5MzM3ODg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79337886?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/d2thebee',
#    'html_url': 'https://github.com/d2thebee',
#    'followers_url': 'https://api.github.com/users/d2thebee/followers',
#    'following_url': 'https://api.github.com/users/d2thebee/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/d2thebee/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/d2thebee/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/d2thebee/subscriptions',
#    'organizations_url': 'https://api.github.com/users/d2thebee/orgs',
#    'repos_url': 'https://api.github.com/users/d2thebee/repos',
#    'events_url': 'https://api.github.com/users/d2thebee/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/d2thebee/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-23T10:04:33Z',
#   'updated_at': '2022-12-23T15:44:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\ndata = pd.read_csv(\'file.csv\', sep=\'¬\', encoding = \'ISO-8859-1\', engine=\'python\', on_bad_lines=\'warn\', nrows=2845060)\n```\n\n\n### Issue Description\n\nRead_csv with on_bad_lines AND nrows at the same time appears to not follow the correct on_bad_lines logic. When I run the above example without the nrows argument, I get the following warning:\r\n\r\nSkipping line 2845058: \'¬\' expected after \'"\'\r\n\r\nBut running with nrows argument included, it errors out with the following message: (same happens when I use on_bad_lines=\'skip\' instead of \'warn\')\r\n\r\nError: \'¬\' expected after \'"\'\n\n### Expected Behavior\n\nThe on_bad_lines logic should continue to work when using nrows so I should see the \'Skipping line\' warning.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 8dab54d6573f7186ff0c3b6364d5e4dd635ff3e7\r\npython           : 3.10.6.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 154 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\n\r\npandas           : 1.5.2\r\nnumpy            : 1.23.2\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 63.2.0\r\npip              : 22.2.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\n...\r\nxlrd             : 2.0.1\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50409/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50409/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50408',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50408/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50408/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50408/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50408',
#   'id': 1509071505,
#   'node_id': 'PR_kwDOAA0YD85GGv7x',
#   'number': 50408,
#   'title': 'STYLE: prohibit parsing exeption messages',
#   'user': {'login': 'luke396',
#    'id': 77875500,
#    'node_id': 'MDQ6VXNlcjc3ODc1NTAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77875500?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luke396',
#    'html_url': 'https://github.com/luke396',
#    'followers_url': 'https://api.github.com/users/luke396/followers',
#    'following_url': 'https://api.github.com/users/luke396/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/luke396/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/luke396/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/luke396/subscriptions',
#    'organizations_url': 'https://api.github.com/users/luke396/orgs',
#    'repos_url': 'https://api.github.com/users/luke396/repos',
#    'events_url': 'https://api.github.com/users/luke396/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/luke396/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-23T08:50:43Z',
#   'updated_at': '2022-12-25T05:15:54Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50408',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50408',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50408.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50408.patch',
#    'merged_at': None},
#   'body': "to fix #50353. \r\n\r\nI'm not quite sure I'm doing it right, so I've just tackled some, and  deal them little by little. Welcome some code review and comments to help me determine that I'm in the right way!",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50408/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50408/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50407',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50407/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50407/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50407/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50407',
#   'id': 1508891678,
#   'node_id': 'I_kwDOAA0YD85Z79we',
#   'number': 50407,
#   'title': 'DEPR: Unnecessary kwargs in groupby ops',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-23T05:03:25Z',
#   'updated_at': '2022-12-23T05:03:25Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Some groupby ops have args and/or kwargs unnecessarily.\r\n\r\n - cummax\r\n - cummin\r\n - cumsum\r\n - cumprod\r\n - take\r\n - skew\r\n\r\nThese should be deprecated. For the cum* methods, the kwargs that are used should be added to the function signature (e.g. `skipna`).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50407/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50407/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1) # 30 number of dictionaries
# Out:
# 30

# %%
data1[0] # one single dictionary
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/50445',
#  'id': 1511387003,
#  'node_id': 'PR_kwDOAA0YD85GOaOX',
#  'number': 50445,
#  'title': 'TST: Add test_ to four tests in test_readlines.py and fix two of them',
#  'user': {'login': 'phershbe',
#   'id': 25594870,
#   'node_id': 'MDQ6VXNlcjI1NTk0ODcw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/25594870?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/phershbe',
#   'html_url': 'https://github.com/phershbe',
#   'followers_url': 'https://api.github.com/users/phershbe/followers',
#   'following_url': 'https://api.github.com/users/phershbe/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/phershbe/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/phershbe/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/phershbe/subscriptions',
#   'organizations_url': 'https://api.github.com/users/phershbe/orgs',
#   'repos_url': 'https://api.github.com/users/phershbe/repos',
#   'events_url': 'https://api.github.com/users/phershbe/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/phershbe/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [{'id': 127685,
#    'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#    'name': 'Testing',
#    'color': 'C4A000',
#    'default': False,
#    'description': 'pandas testing functions or related to the test suite'}],
#  'state': 'open',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#   'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#   'id': 1945020,
#   'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#   'number': 42,
#   'title': '2.0',
#   'description': '',
#   'creator': {'login': 'jreback',
#    'id': 953992,
#    'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jreback',
#    'html_url': 'https://github.com/jreback',
#    'followers_url': 'https://api.github.com/users/jreback/followers',
#    'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jreback/orgs',
#    'repos_url': 'https://api.github.com/users/jreback/repos',
#    'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jreback/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'open_issues': 53,
#   'closed_issues': 855,
#   'state': 'open',
#   'created_at': '2016-08-16T13:21:24Z',
#   'updated_at': '2022-12-27T08:16:07Z',
#   'due_on': '2023-01-31T08:00:00Z',
#   'closed_at': None},
#  'comments': 0,
#  'created_at': '2022-12-27T03:03:14Z',
#  'updated_at': '2022-12-27T07:51:45Z',
#  'closed_at': None,
#  'author_association': 'NONE',
#  'active_lock_reason': None,
#  'draft': False,
#  'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50445',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50445',
#   'diff_url': 'https://github.com/pandas-dev/pandas/pull/50445.diff',
#   'patch_url': 'https://github.com/pandas-dev/pandas/pull/50445.patch',
#   'merged_at': None},
#  'body': "Four tests in https://github.com/pandas-dev/pandas/blob/main/pandas/tests/io/json/test_readlines.py weren't running because they didn't have `test_` in front of their names, fixed those.\r\n\r\nTwo of those tests were not passing because the JSON data was turning booleans into 1s and 0s which was conflicting with the booleans in the compared data, so added `int` before all of the booleans in the compared data. Had detailed comments explaining this but shortened them in order to pass Flake8.\r\n\r\n- [x] closes #50378\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).",
#  'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50445/timeline',
#  'performed_via_github_app': None,
#  'state_reason': None}

# %%
data1[0]['user']['id']
# Out:
# 25594870

# %%
for i in range(len(data1)):
  print(data1[i]['user']['id'])
# Out:
# 25594870
# 45562402
# 10662138
# 684275
# 8078968
# 74217512
# 33491632
# 8519523
# 61934744
# 33491632
# 8078968
# 61934744
# 61934744
# 61934744
# 61934744
# 73883983
# 61934744
# 609873
# 33491632
# 47963215
# 45562402
# 61934744
# 45562402
# 45562402
# 1020496
# 1020496
# 1020496
# 79337886
# 77875500
# 45562402

# %%
import pandas as pd

# %%
df = pd.DataFrame(data1)

# %%
dict(data1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-793b6caf6c9c> in <module>
# ----> 1 dict(data1)
#
# ValueError: dictionary update sequence element #0 has length 30; 2 is required

# %%
keys = data1.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-356f95df4b15> in <module>
# ----> 1 keys = data1.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %% [markdown]
# ---

# %%
k = {'a':'dhd','b':'adada','c':'ascakaj'}

# %%
keys = k.keys()

# %%
values = k.values()

# %%
q = pd.DataFrame()

# %%
q["keys"] = keys

# %%
q["values"] = values

# %%
q
# Out:
#   keys   values
# 0    a      dhd
# 1    b    adada
# 2    c  ascakaj

# %% [markdown]
# ---

# %%
pd.DataFrame(data1 , columns = ['url','repository_url','labels_url'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
pd.DataFrame(data1 , columns = ['id','url','repository_url','labels_url'])
# Out:
#             id                                                url  \
# 0   1511414515  https://api.github.com/repos/pandas-dev/pandas...
# 1   1511387003  https://api.github.com/repos/pandas-dev/pandas...
# 2   1511382949  https://api.github.com/repos/pandas-dev/pandas...
# 3   1511235443  https://api.github.com/repos/pandas-dev/pandas...
# 4   1511176496  https://api.github.com/repos/pandas-dev/pandas...
# 5   1511148698  https://api.github.com/repos/pandas-dev/pandas...
# 6   1511090425  https://api.github.com/repos/pandas-dev/pandas...
# 7   1511026179  https://api.github.com/repos/pandas-dev/pandas...
# 8   1510379713  https://api.github.com/repos/pandas-dev/pandas...
# 9   1510306930  https://api.github.com/repos/pandas-dev/pandas...
# 10  1510302903  https://api.github.com/repos/pandas-dev/pandas...
# 11  1510215965  https://api.github.com/repos/pandas-dev/pandas...
# 12  1510180067  https://api.github.com/repos/pandas-dev/pandas...
# 13  1510170092  https://api.github.com/repos/pandas-dev/pandas...
# 14  1510108437  https://api.github.com/repos/pandas-dev/pandas...
# 15  1510105970  https://api.github.com/repos/pandas-dev/pandas...
# 16  1510092883  https://api.github.com/repos/pandas-dev/pandas...
# 17  1510049222  https://api.github.com/repos/pandas-dev/pandas...
# 18  1509890555  https://api.github.com/repos/pandas-dev/pandas...
# 19  1509807186  https://api.github.com/repos/pandas-dev/pandas...
# 20  1509642413  https://api.github.com/repos/pandas-dev/pandas...
# 21  1509630900  https://api.github.com/repos/pandas-dev/pandas...
# 22  1509593635  https://api.github.com/repos/pandas-dev/pandas...
# 23  1509536828  https://api.github.com/repos/pandas-dev/pandas...
# 24  1509519854  https://api.github.com/repos/pandas-dev/pandas...
# 25  1509379729  https://api.github.com/repos/pandas-dev/pandas...
# 26  1509324259  https://api.github.com/repos/pandas-dev/pandas...
# 27  1509310192  https://api.github.com/repos/pandas-dev/pandas...
# 28  1509146751  https://api.github.com/repos/pandas-dev/pandas...
# 29  1509071505  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
df2 = pd.DataFrame(data1 , columns = ['url','repository_url','labels_url','user'])

# %%
df2 = pd.DataFrame(data1 , columns = ['url','repository_url','labels_url','user','user''login'])

# %%
df2.to_csv('json_res.csv')

# %%
ls
# Out:
# json_res.csv  sample_data/

# %%
user = {'login': 'phershbe', 'id': 25594870, 'node_id': 'MDQ6VXNlcjI1NTk0ODcw', 'avatar_url': 'https://avatars.githubusercontent.com/u/25594870?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phershbe', 'html_url': 'https://github.com/phershbe', 'followers_url': 'https://api.github.com/users/phershbe/followers', 'following_url': 'https://api.github.com/users/phershbe/following{/other_user}', 'gists_url': 'https://api.github.com/users/phershbe/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/phershbe/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/phershbe/subscriptions', 'organizations_url': 'https://api.github.com/users/phershbe/orgs', 'repos_url': 'https://api.github.com/users/phershbe/repos', 'events_url': 'https://api.github.com/users/phershbe/events{/privacy}', 'received_events_url': 'https://api.github.com/users/phershbe/received_events', 'type': 'User', 'site_admin': False}
